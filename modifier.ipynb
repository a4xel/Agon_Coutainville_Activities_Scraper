# %%
import pandas as pd
import os

# %%
file_path = os.getcwd()

dataset_july= pd.read_csv(file_path+"/results_tides/juillet-2022.csv",index_col=0 )

# %%
dataset_july
# Out:
#            Date  Coeff1  Coeff2 first_high_tide second_high_tide  \
# 0       jeudi 7      52      50           00h55            13h29
# 1    vendredi 8      49      49           01h52            14h32
# 2      samedi 9      50      52           03h01            15h44
# 3   dimanche 10      56      60           04h14            16h56
# 4      lundi 11      64      69           05h25            18h02
# 5      mardi 12      75      80           06h31            19h04
# 6   mercredi 13      85      89           07h33            20h00
# 7      jeudi 14      93      95           08h30            20h53
# 8   vendredi 15      97      98           09h23            21h43
# 9     samedi 16      97      96           10h11            22h30
# 10  dimanche 17      93      89           10h57            23h14
# 11     lundi 18      85      79           11h39            23h56
# 12     mardi 19      74      67           12h19            00h37
# ...
