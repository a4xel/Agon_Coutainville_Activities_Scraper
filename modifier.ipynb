# %%
import pandas as pd
import os

# %%
file_path = os.getcwd()

dataset_july= pd.read_csv(file_path+"/results_tides/juillet-2022.csv",index_col=0 )

# %%
dataset_july
# Out:
#            Date  Coeff1 first_high_tide first_low_tide  Coeff2  \
# 0       jeudi 7      52           00h55          07h58      50
# 1    vendredi 8      49           01h52          08h54      49
# 2      samedi 9      50           03h01          10h06      52
# 3   dimanche 10      56           04h14          11h24      60
# 4      lundi 11      64           05h25          12h38      69
# 5      mardi 12      75           06h31          13h44      80
# 6   mercredi 13      85           07h33          14h47      89
# 7      jeudi 14      93           08h30          15h45      95
# 8   vendredi 15      97           09h23          16h36      98
# 9     samedi 16      97           10h11          17h23      96
# 10  dimanche 17      93           10h57          18h06      89
# 11     lundi 18      85           11h39          18h46      79
# 12     mardi 19      74           12h19          19h23      67
# 13  mercredi 20      62           13h00          20h01      56
# ...
